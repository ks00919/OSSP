# %%
# 구글 드라이브 연동
from google.colab import drive
drive.mount('/content/drive')

# %%
# conda 설치
# install_miniconda python3.7용으로 빌드된 버전을 사용하여 Miniconda 4.9.2 배포 설치

# !pip install -q condacolab
import condacolab
condacolab.install_miniconda()
# Out:
# ⏬ Downloading https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:18
# 🔁 Restarting kernel...

# %%
# conda 체크
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# conda 업데이트
# !conda config --set channel_priority false
# !conda update --all
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-2ee8ae0d1a44> in <module>
#       1 # conda 업데이트
# ----> 2 get_ipython().run_line_magic('conda', 'config --set channel_priority false')
#       3 get_ipython().run_line_magic('conda', 'update --all')
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2312                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2313             with self.builtin_trap:
# -> 2314                 result = fn(*args, **kwargs)
#    2315             return result
#    2316
#
# <decorator-gen-100> in conda(self, line)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/magics/packaging.py in conda(self, line)
#      78         """
#      79         if not _is_conda_environment():
# ---> 80             raise ValueError("The python kernel does not appear to be a conda environment.  "
#      81                              "Please use ``%pip install`` instead.")
#      82
#
# ValueError: The python kernel does not appear to be a conda environment.  Please use ``%pip install`` instead.

# %%
# !conda config --append channels conda-forge
# !conda install openmm
# !conda env update -n base -f environment.yml
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - openmm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.12.7  |       ha878542_0         143 KB  conda-forge
#     cudatoolkit-11.2.2         |      hbe64b41_10       876.8 MB  conda-forge
#     fftw-3.3.10                |nompi_h77c792f_102         6.4 MB  conda-forge
#     libblas-3.9.0              |16_linux64_openblas          13 KB  conda-forge
#     libcblas-3.9.0             |16_linux64_openblas          13 KB  conda-forge
#     libgfortran-ng-12.2.0      |      h69a702a_19          22 KB  conda-forge
#     libgfortran5-12.2.0        |      h337968e_19         1.8 MB  conda-forge
#     liblapack-3.9.0            |16_linux64_openblas          13 KB  conda-forge
#     libopenblas-0.3.21         |       h043d6bf_0         5.4 MB
#     numpy-1.22.3               |   py38h99721a1_2         6.8 MB  conda-forge
#     ocl-icd-2.3.1              |       h7f98852_0         119 KB  conda-forge
#     ocl-icd-system-1.0.0       |                1           4 KB  conda-forge
#     openmm-7.7.0               |   py38h4b4c9af_1        11.3 MB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       908.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.2.2-hbe64b41_10
#   fftw               conda-forge/linux-64::fftw-3.3.10-nompi_h77c792f_102
#   libblas            conda-forge/linux-64::libblas-3.9.0-16_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-16_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.2.0-h69a702a_19
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.2.0-h337968e_19
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-16_linux64_openblas
#   libopenblas        pkgs/main/linux-64::libopenblas-0.3.21-h043d6bf_0
#   numpy              conda-forge/linux-64::numpy-1.22.3-py38h99721a1_2
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.1-h7f98852_0
#   ocl-icd-system     conda-forge/linux-64::ocl-icd-system-1.0.0-1
#   openmm             conda-forge/linux-64::openmm-7.7.0-py38h4b4c9af_1
#   python_abi         conda-forge/linux-64::python_abi-3.8-2_cp38
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.10.11~ --> conda-forge::ca-certificates-2022.12.7-ha878542_0
#
#
#
# Downloading and Extracting Packages
# liblapack-3.9.0      | 13 KB     | :   0% 0/1 [00:00<?, ?it/s]
# cudatoolkit-11.2.2   | 876.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# ca-certificates-2022 | 143 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libopenblas-0.3.21   | 5.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# ocl-icd-system-1.0.0 | 4 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# python_abi-3.8       | 4 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libblas-3.9.0        | 13 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# ocl-icd-2.3.1        | 119 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# numpy-1.22.3         | 6.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# fftw-3.3.10          | 6.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# openmm-7.7.0         | 11.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-12.2.0  | 1.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 13 KB     | :   0% 0/1 [00:00<?, ?it/s]
# cudatoolkit-11.2.2   | 876.8 MB  | :   0% 0.00012473819531483304/1 [00:00<13:37, 817.26s/it]
#
#
# libopenblas-0.3.21   | 5.4 MB    | :  17% 0.17340294099177508/1 [00:00<00:00,  1.72it/s]
#
#
#
# ocl-icd-system-1.0.0 | 4 KB      | : 100% 1.0/1 [00:00<00:00,  9.55it/s]
#
#
#
#
# python_abi-3.8       | 4 KB      | : 100% 1.0/1 [00:00<00:00,  8.40it/s]
#
#
#
#
#
# libblas-3.9.0        | 13 KB     | : 100% 1.0/1 [00:00<00:00,  8.19it/s]
#
#
#
#
#
#
# liblapack-3.9.0      | 13 KB     | : 100% 1.0/1 [00:00<00:00,  6.40it/s]
#
# ca-certificates-2022 | 143 KB    | : 100% 1.0/1 [00:00<00:00,  5.96it/s]
#
#
#
#
#
#
#
#
# fftw-3.3.10          | 6.4 MB    | :   0% 0.002448080272647768/1 [00:00<01:03, 63.62s/it]
#
# ca-certificates-2022 | 143 KB    | : 100% 1.0/1 [00:00<00:00,  5.96it/s]
#
#
#
#
#
#
#
# numpy-1.22.3         | 6.8 MB    | :   0% 0.0022978375587046724/1 [00:00<01:11, 71.76s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   0% 0.002138369062539995/1 [00:00<01:21, 81.92s/it]
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     | :  72% 0.7159587484705471/1 [00:00<00:00,  3.73it/s]
#
#
# libopenblas-0.3.21   | 5.4 MB    | :  58% 0.5751197542893873/1 [00:00<00:00,  3.03it/s]
#
#
#
# ocl-icd-system-1.0.0 | 4 KB      | : 100% 1.0/1 [00:00<00:00,  9.55it/s]
#
#
#
#
# python_abi-3.8       | 4 KB      | : 100% 1.0/1 [00:00<00:00,  8.40it/s]
#
#
#
#
#
#
#
#
#
#
# openmm-7.7.0         | 11.3 MB   | :   0% 0.0013864308831541031/1 [00:00<02:58, 178.48s/it]
#
#
#
#
#
#
#
#
# fftw-3.3.10          | 6.4 MB    | :  30% 0.3011138735356755/1 [00:00<00:00,  1.43it/s]
#
#
#
#
#
#
#
# numpy-1.22.3         | 6.8 MB    | :  31% 0.3079102328664261/1 [00:00<00:00,  1.42it/s]
# cudatoolkit-11.2.2   | 876.8 MB  | :   0% 0.0042054591563286566/1 [00:00<01:02, 62.54s/it]
#
#
# libopenblas-0.3.21   | 5.4 MB    | :  97% 0.9681664205374109/1 [00:00<00:00,  3.43it/s]
#
#
#
#
#
# libblas-3.9.0        | 13 KB     | : 100% 1.0/1 [00:00<00:00,  8.19it/s]
#
#
#
#
#
#
#
#
#
#
# openmm-7.7.0         | 11.3 MB   | :  21% 0.2135103560057319/1 [00:00<00:01,  1.29s/it]
#
#
#
#
#
#
#
#
# fftw-3.3.10          | 6.4 MB    | :  56% 0.560610382436339/1 [00:00<00:00,  1.90it/s]
#
#
#
#
#
#
#
# numpy-1.22.3         | 6.8 MB    | :  57% 0.5652680394413495/1 [00:00<00:00,  1.87it/s]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-12.2.0  | 1.8 MB    | :   1% 0.008908942710126037/1 [00:00<00:43, 43.56s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   1% 0.0061299913126146525/1 [00:00<00:57, 57.93s/it]
#
#
#
#
#
#
#
#
#
#
# openmm-7.7.0         | 11.3 MB   | :  39% 0.3923599399326112/1 [00:00<00:00,  1.12it/s]
#
#
#
#
#
#
#
#
# fftw-3.3.10          | 6.4 MB    | :  83% 0.8274511321549457/1 [00:00<00:00,  2.18it/s]
#
#
#
#
#
#
#
# numpy-1.22.3         | 6.8 MB    | :  84% 0.8410085464859102/1 [00:00<00:00,  2.18it/s]
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     | : 100% 1.0/1 [00:00<00:00,  3.73it/s]
# cudatoolkit-11.2.2   | 876.8 MB  | :   1% 0.008321819601718147/1 [00:00<00:52, 52.98s/it]
#
#
#
#
#
#
# ocl-icd-2.3.1        | 119 KB    | : 100% 1.0/1 [00:00<00:00,  2.05it/s]
#
#
#
#
#
#
# ocl-icd-2.3.1        | 119 KB    | : 100% 1.0/1 [00:00<00:00,  2.05it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 13 KB     | : 100% 1.0/1 [00:00<00:00,  1.91it/s]
#
#
#
#
#
#
#
#
#
#
# openmm-7.7.0         | 11.3 MB   | :  59% 0.5920059871068021/1 [00:00<00:00,  1.41it/s]
# cudatoolkit-11.2.2   | 876.8 MB  | :   1% 0.011921407523660471/1 [00:00<00:40, 40.54s/it]
#
#
#
#
#
#
#
#
#
#
# openmm-7.7.0         | 11.3 MB   | :  92% 0.9219765372974786/1 [00:00<00:00,  2.00it/s]
# cudatoolkit-11.2.2   | 876.8 MB  | :   2% 0.015717012609668964/1 [00:00<00:33, 34.49s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   2% 0.02122331294570945/1 [00:00<00:26, 26.84s/it]
#
#
# libopenblas-0.3.21   | 5.4 MB    | : 100% 1.0/1 [00:00<00:00,  3.43it/s]
# cudatoolkit-11.2.2   | 876.8 MB  | :   3% 0.026337578953617605/1 [00:00<00:23, 24.19s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   3% 0.033465475828750924/1 [00:01<00:19, 19.79s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   4% 0.03852628261009557/1 [00:01<00:20, 21.82s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   5% 0.04506612799303039/1 [00:01<00:18, 19.47s/it]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-12.2.0  | 1.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-12.2.0  | 1.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 13 KB     | : 100% 1.0/1 [00:01<00:00,  1.91it/s]
# cudatoolkit-11.2.2   | 876.8 MB  | :   5% 0.05110702059470588/1 [00:01<00:17, 18.54s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   6% 0.057379569844823196/1 [00:01<00:16, 17.70s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   6% 0.06309970708711768/1 [00:01<00:17, 18.83s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   7% 0.06849908897003117/1 [00:01<00:17, 18.89s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   7% 0.07436178414982832/1 [00:01<00:17, 18.52s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   8% 0.07981462525930531/1 [00:01<00:17, 18.89s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   9% 0.08674650497037246/1 [00:01<00:15, 17.35s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   9% 0.09255574092360612/1 [00:02<00:16, 17.68s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  10% 0.0986500927518451/1 [00:02<00:15, 17.30s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  11% 0.10520775787696775/1 [00:02<00:14, 16.66s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  11% 0.11124865047864324/1 [00:02<00:15, 17.27s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  12% 0.11707570617406472/1 [00:02<00:15, 17.68s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  12% 0.12281366315854704/1 [00:02<00:15, 17.75s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  13% 0.12962080467429934/1 [00:02<00:14, 16.77s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  14% 0.13560823804941136/1 [00:02<00:14, 17.06s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  14% 0.14148875297139632/1 [00:02<00:15, 17.50s/it]
#
#
#
#
#
#
#
#
# fftw-3.3.10          | 6.4 MB    | : 100% 1.0/1 [00:02<00:00,  2.18it/s]
# cudatoolkit-11.2.2   | 876.8 MB  | :  15% 0.14738708763556915/1 [00:03<00:14, 17.35s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  15% 0.15317850384661497/1 [00:03<00:14, 17.38s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  16% 0.15920157670610263/1 [00:03<00:14, 17.15s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  17% 0.16595525899529143/1 [00:03<00:13, 16.39s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  17% 0.17206743056571824/1 [00:03<00:15, 18.47s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  18% 0.17764500987051007/1 [00:03<00:15, 18.62s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  18% 0
/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  79% 0.7912500123663616/1 [00:10<00:01,  9.24s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  80% 0.8043297031322313/1 [00:10<00:01,  8.76s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  82% 0.8163758488512065/1 [00:11<00:01,  9.13s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  83% 0.833215505218709/1 [00:11<00:01,  7.96s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  85% 0.846259556500203/1 [00:11<00:01,  8.15s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  86% 0.8588937537113768/1 [00:11<00:01,  8.85s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  87% 0.8705656848444076/1 [00:11<00:01, 10.78s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  88% 0.8806160194383456/1 [00:11<00:01, 10.98s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  90% 0.8958697187511309/1 [00:11<00:00,  9.48s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  91% 0.907078336587278/1 [00:11<00:00,  9.97s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  92% 0.9175741647359118/1 [00:12<00:00, 10.35s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  93% 0.9275532203610984/1 [00:12<00:00, 10.68s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  94% 0.9371402416581528/1 [00:12<00:00, 10.81s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  95% 0.9465312457911409/1 [00:12<00:00, 11.05s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  96% 0.9556727735334994/1 [00:12<00:00, 14.72s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  96% 0.9638698549399027/1 [00:12<00:00, 14.08s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  98% 0.9782860263698598/1 [00:12<00:00, 11.26s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :  99% 0.9880690648309803/1 [00:12<00:00, 11.16s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | : 100% 0.9976739058702224/1 [00:13<00:00, 12.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# | By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
#
# SpecNotFound: Invalid name 'base', try the format: user/package

# %%
# conda 가상환경 생성
# !conda create -n my_env python==3.7
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/my_env
#
#   added / updated specs:
#     - python==3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     libgcc-ng-12.2.0           |      h65d4601_19         931 KB  conda-forge
#     libgomp-12.2.0             |      h65d4601_19         455 KB  conda-forge
#     libstdcxx-ng-12.2.0        |      h46fd767_19         4.3 MB  conda-forge
#     wheel-0.38.4               |     pyhd8ed1ab_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   ca-certificates    conda-forge/linux-64::ca-certificates-2022.12.7-ha878542_0
#   certifi            pkgs/main/linux-64::certifi-2022.12.7-py37h06a4308_0
#   libedit            pkgs/main/linux-64::libedit-3.1.20221030-h5eee18b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hf484d3e_1007
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-12.2.0-h65d4601_19
#   libgomp            conda-forge/linux-64::libgomp-12.2.0-h65d4601_19
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-12.2.0-h46fd767_19
#   ncurses            pkgs/main/linux-64::ncurses-6.3-h5eee18b_3
#   openssl            pkgs/main/linux-64::openssl-1.0.2u-h7b6447c_0
#   pip                pkgs/main/linux-64::pip-22.3.1-py37h06a4308_0
#   python             pkgs/main/linux-64::python-3.7.0-h6e4f718_3
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   setuptools         pkgs/main/linux-64::setuptools-65.6.3-py37h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.33.0-h62c20be_0
#   tk                 pkgs/main/linux-64::tk-8.6.12-h1ccaba5_0
#   wheel              conda-forge/noarch::wheel-0.38.4-pyhd8ed1ab_0
#   xz                 pkgs/main/linux-64::xz-5.2.8-h5eee18b_0
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_0
#
#
#
# Downloading and Extracting Packages
# _libgcc_mutex-0.1    | 3 KB      | :   0% 0/1 [00:00<?, ?it/s]
# libgomp-12.2.0       | 455 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# wheel-0.38.4         | 32 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libgcc-ng-12.2.0     | 931 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libstdcxx-ng-12.2.0  | 4.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# _openmp_mutex-4.5    | 23 KB     | :   0% 0/1 [00:00<?, ?it/s]
# libgomp-12.2.0       | 455 KB    | :  91% 0.9137601139454469/1 [00:00<00:00,  9.12it/s]
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00,  8.62it/s]
#
#
#
#
# _openmp_mutex-4.5    | 23 KB     | :  69% 0.6936200838237162/1 [00:00<00:00,  5.89it/s]
#
# wheel-0.38.4         | 32 KB     | : 100% 1.0/1 [00:00<00:00,  7.33it/s]
#
# wheel-0.38.4         | 32 KB     | : 100% 1.0/1 [00:00<00:00,  7.33it/s]
#
#
# libgcc-ng-12.2.0     | 931 KB    | :   2% 0.01717738925490558/1 [00:00<00:08,  8.72s/it]
#
#
#
#
# _openmp_mutex-4.5    | 23 KB     | : 100% 1.0/1 [00:00<00:00,  5.89it/s]
#
#
#
# libstdcxx-ng-12.2.0  | 4.3 MB    | :  94% 0.9397553076262278/1 [00:00<00:00,  5.36it/s]
# libgomp-12.2.0       | 455 KB    | : 100% 1.0/1 [00:00<00:00,  9.12it/s]
#
#
# libgcc-ng-12.2.0     | 931 KB    | : 100% 1.0/1 [00:00<00:00,  2.98it/s]
#
#
# libgcc-ng-12.2.0     | 931 KB    | : 100% 1.0/1 [00:00<00:00,  2.98it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate my_env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# conda 가상환경 실행
# !source activate my_env

# %%
# conda를 통한 CUDNN 라이브러리 설치
# !conda install -c anaconda cudnn==8.2.1
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# \
# CondaError: KeyboardInterrupt
#
# ^C

# %%
# T5 모델 설치
# !pip install t5==0.6.4 mesh_tensorflow==0.1.17 konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting t5==0.6.4
#   Downloading t5-0.6.4-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 16.0 MB/s eta 0:00:00
# Collecting mesh_tensorflow==0.1.17
#   Downloading mesh_tensorflow-0.1.17-py3-none-any.whl (342 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.8/342.8 kB 37.3 MB/s eta 0:00:00
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 58.2 MB/s eta 0:00:00
# Collecting babel
#   Downloading Babel-2.11.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 107.1 MB/s eta 0:00:00
# Collecting absl-py
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 17.2 MB/s eta 0:00:00
# ERROR: Operation cancelled by user
